# %% [markdown]
# # RAG
# В этом ноутбуке реализован подход Retrieval-Augmented Generation (RAG) для генерации описаний одежды. Возможности генеративной модели комбинируются с релевантными примерами из обучающего датасета.
#
# Для этого используется:
# - модель `SentenceTransformers` модель для построения эмбеддингов входных характеристик
# - FAISS-индекс для поиска ближайших соседей
# - извлеченные примеры, которые вместе с входными характеристиками подаются в промпт модели.
#
# Цель — повысить качество описаний за счёт ориентации на реальные примеры и понизить вероятность галлюцинаций.

# %%
# !pip install sentence-transformers faiss-cpu
# Out:
# Requirement already satisfied: sentence-transformers in /usr/local/lib/python3.11/dist-packages (4.1.0)
# Collecting faiss-cpu
#   Downloading faiss_cpu-1.11.0.post1-cp311-cp311-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (5.0 kB)
# Requirement already satisfied: transformers<5.0.0,>=4.41.0 in /usr/local/lib/python3.11/dist-packages (from sentence-transformers) (4.53.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from sentence-transformers) (4.67.1)
# Requirement already satisfied: torch>=1.11.0 in /usr/local/lib/python3.11/dist-packages (from sentence-transformers) (2.6.0+cu124)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.11/dist-packages (from sentence-transformers) (1.6.1)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (from sentence-transformers) (1.16.0)
# Requirement already satisfied: huggingface-hub>=0.20.0 in /usr/local/lib/python3.11/dist-packages (from sentence-transformers) (0.33.4)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.11/dist-packages (from sentence-transformers) (11.3.0)
# Requirement already satisfied: typing_extensions>=4.5.0 in /usr/local/lib/python3.11/dist-packages (from sentence-transformers) (4.14.1)
# Requirement already satisfied: numpy<3.0,>=1.25.0 in /usr/local/lib/python3.11/dist-packages (from faiss-cpu) (2.0.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from faiss-cpu) (25.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.20.0->sentence-transformers) (3.18.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.20.0->sentence-transformers) (2025.7.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.20.0->sentence-transformers) (6.0.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.20.0->sentence-transformers) (2.32.3)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.20.0->sentence-transformers) (1.1.5)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers) (3.1.6)
# Collecting nvidia-cuda-nvrtc-cu12==12.4.127 (from torch>=1.11.0->sentence-transformers)
#   Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.4.127 (from torch>=1.11.0->sentence-transformers)
#   Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.4.127 (from torch>=1.11.0->sentence-transformers)
#   Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch>=1.11.0->sentence-transformers)
#   Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.4.5.8 (from torch>=1.11.0->sentence-transformers)
#   Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.2.1.3 (from torch>=1.11.0->sentence-transformers)
#   Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.5.147 (from torch>=1.11.0->sentence-transformers)
#   Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.6.1.9 (from torch>=1.11.0->sentence-transformers)
#   Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.3.1.170 (from torch>=1.11.0->sentence-transformers)
#   Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers) (12.4.127)
# Collecting nvidia-nvjitlink-cu12==12.4.127 (from torch>=1.11.0->sentence-transformers)
#   Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch>=1.11.0->sentence-transformers) (1.3.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.11/dist-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (2024.11.6)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /usr/local/lib/python3.11/dist-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (0.21.2)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.11/dist-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (0.5.3)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn->sentence-transformers) (1.5.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn->sentence-transformers) (3.6.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch>=1.11.0->sentence-transformers) (3.0.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers) (2025.7.14)
# Downloading faiss_cpu-1.11.0.post1-cp311-cp311-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (31.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 31.3/31.3 MB 71.4 MB/s eta 0:00:00
# Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl (363.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 2.7 MB/s eta 0:00:00
# Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (13.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 89.3 MB/s eta 0:00:00
# Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (24.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 66.9 MB/s eta 0:00:00
# Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (883 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 66.1 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.1 MB/s eta 0:00:00
# Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl (211.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 6.6 MB/s eta 0:00:00
# Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 12.8 MB/s eta 0:00:00
# Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl (127.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.9 MB/s eta 0:00:00
# Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl (207.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 6.3 MB/s eta 0:00:00
# Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 68.3 MB/s eta 0:00:00
# Installing collected packages: nvidia-nvjitlink-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, faiss-cpu, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.5.82
#     Uninstalling nvidia-nvjitlink-cu12-12.5.82:
#       Successfully uninstalled nvidia-nvjitlink-cu12-12.5.82
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.6.82
#     Uninstalling nvidia-curand-cu12-10.3.6.82:
#       Successfully uninstalled nvidia-curand-cu12-10.3.6.82
#   Attempting uninstall: nvidia-cufft-cu12
#     Found existing installation: nvidia-cufft-cu12 11.2.3.61
#     Uninstalling nvidia-cufft-cu12-11.2.3.61:
#       Successfully uninstalled nvidia-cufft-cu12-11.2.3.61
#   Attempting uninstall: nvidia-cuda-runtime-cu12
#     Found existing installation: nvidia-cuda-runtime-cu12 12.5.82
#     Uninstalling nvidia-cuda-runtime-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-runtime-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-nvrtc-cu12
#     Found existing installation: nvidia-cuda-nvrtc-cu12 12.5.82
#     Uninstalling nvidia-cuda-nvrtc-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-nvrtc-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-cupti-cu12
#     Found existing installation: nvidia-cuda-cupti-cu12 12.5.82
#     Uninstalling nvidia-cuda-cupti-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-cupti-cu12-12.5.82
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.5.3.2
#     Uninstalling nvidia-cublas-cu12-12.5.3.2:
#       Successfully uninstalled nvidia-cublas-cu12-12.5.3.2
#   Attempting uninstall: nvidia-cusparse-cu12
#     Found existing installation: nvidia-cusparse-cu12 12.5.1.3
#     Uninstalling nvidia-cusparse-cu12-12.5.1.3:
#       Successfully uninstalled nvidia-cusparse-cu12-12.5.1.3
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.3.0.75
#     Uninstalling nvidia-cudnn-cu12-9.3.0.75:
#       Successfully uninstalled nvidia-cudnn-cu12-9.3.0.75
#   Attempting uninstall: nvidia-cusolver-cu12
#     Found existing installation: nvidia-cusolver-cu12 11.6.3.83
#     Uninstalling nvidia-cusolver-cu12-11.6.3.83:
#       Successfully uninstalled nvidia-cusolver-cu12-11.6.3.83
# Successfully installed faiss-cpu-1.11.0.post1 nvidia-cublas-cu12-12.4.5.8 nvidia-cuda-cupti-cu12-12.4.127 nvidia-cuda-nvrtc-cu12-12.4.127 nvidia-cuda-runtime-cu12-12.4.127 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.2.1.3 nvidia-curand-cu12-10.3.5.147 nvidia-cusolver-cu12-11.6.1.9 nvidia-cusparse-cu12-12.3.1.170 nvidia-nvjitlink-cu12-12.4.127

# %% [markdown]
# ## 1. Загрузка и подготовка данных

# %%
import faiss
import pandas as pd
import numpy as np
import openai
from sentence_transformers import SentenceTransformer

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# беру те же датасеты, что и в rut5, gpt
df_train = pd.read_csv('drive/MyDrive/proj_cloth_desc_gen/df_train.csv', index_col =0).reset_index(drop=True)
df_val = pd.read_csv('drive/MyDrive/proj_cloth_desc_gen/df_val.csv', index_col =0).reset_index(drop=True)

# %%
# удаляю инструкцию
df_train["input"] = df_train["input"].str.replace("Сгенерируй описание одежды для карточки товара:\n", "", regex=False)
df_val["input"] = df_val["input"].str.replace("Сгенерируй описание одежды для карточки товара:\n", "", regex=False)

# %% [markdown]
# ## 2. Подбор параметров RAG (SentenceTransformer + нормализация)
# Сравним на нескольких примеров качество генерации и найденные похожие примеры для разных моделей построения эмбеддингов:
# - all-MiniLM-L6-v2
# - paraphrase-multilingual-MiniLM-L12-v2
#
# А также с использованием и без использования нормализации эмбеддингов

# %%
# функция построения FAISS индекса
def build_faiss_index(model_name="all-MiniLM-L6-v2", normalize=False):

    # Переводим входные тексты в эмбеддинги
    model = SentenceTransformer(model_name)
    texts = df_train["input"].tolist()
    embeddings = model.encode(texts, convert_to_numpy=True)

    if normalize:
        # нормализуем эмбеддинги по длине (норма 1)
        embeddings = embeddings / np.linalg.norm(embeddings, axis=1, keepdims=True)
        # поиск ближайших соседей по косинусному сходству
        index = faiss.IndexFlatIP(embeddings.shape[1])
    else:
        # поиск по евклидовому расстоянию
        index = faiss.IndexFlatL2(embeddings.shape[1])

    # добавляем эмбеддинг в индекс
    index.add(embeddings)
    return index, embeddings, model

# %%
# функция поиска k ближайших примеров из train датасета на основе FAISS-индекса
def retrieve_similar_examples(query, index, model, normalize=False, k=3):
    
    query_emb = model.encode(query, convert_to_numpy=True).reshape(1, -1)
    if normalize:
        query_emb = query_emb / np.linalg.norm(query_emb, axis=1, keepdims=True)

    distances, indices = index.search(query_emb, k)
    return df_train.iloc[indices[0]]

# функция генерации описания при помощи RAG
def generate_description_rag(input_text, index, model, normalize=False, k=3):
    # K близжайших примеров на train датасете по входному тексту
    retrieved = retrieve_similar_examples(input_text, index, model, normalize, k)

    # добавляем инструкцию + похожие примеры + входной текст
    prompt = "Сгенерируй описание одежды по характеристикам. Не выдумывай того, чего нет.\n"
    for _, row in retrieved.iterrows():
        prompt += f"\nХарактеристики:\n{row['input']}\nОписание:\n{row['final_desc']}\n"

    prompt += f"\nХарактеристики:\n{input_text}\nОписание:\n"

    # генерация через OpenAI
    response = client.chat.completions.create(
        model="gpt-4",
        messages=[{"role": "user", "content": prompt}],
        temperature=0.7,
        top_p=0.95,
        max_tokens=512,
        timeout=60
    )
    return retrieved, response.choices[0].message.content

# %%
from getpass import getpass
import openai

openai.api_key = getpass("Введи OpenAI API ключ: ")
# Out:
# Введи OpenAI API ключ: ··········

# %%
client = openai.OpenAI(api_key=openai.api_key)

# %%
# рандломные примеры
df_sample = df_val.sample(5, random_state = 42)
inp = df_sample['input'].tolist()

# %%
# all-MiniLM-L6-v2 без нормализации
idx_1, emb_1, model_1 = build_faiss_index(model_name="all-MiniLM-L6-v2", normalize=False)
emb_1.shape
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md: 0.00B [00:00, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/612 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/90.9M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/350 [00:00<?, ?B/s]
# vocab.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
# (44727, 384)

# %%
serch_list, gen_list = [], []
for i in inp:
  df_serch, gen_rag = generate_description_rag(i, idx_1, model_1, normalize=False, k=3)
  serch_list.append(df_serch['input'].tolist())
  gen_list.append(gen_rag)
df_sample['l6_k'] = serch_list
df_sample['l6_gen'] = gen_list

# %%
# all-MiniLM-L6-v2 с нормализацией
idx_2, emb_2, model_2 = build_faiss_index(model_name="all-MiniLM-L6-v2", normalize=True)
emb_2.shape
# Out:
# (44727, 384)

# %%
serch_list, gen_list = [], []
for i in inp:
  df_serch, gen_rag = generate_description_rag(i, idx_2, model_2, normalize=True, k=3)
  serch_list.append(df_serch['input'].tolist())
  gen_list.append(gen_rag)
df_sample['l6_norm_k'] = serch_list
df_sample['l6_norm_gen'] = gen_list

# %%
# paraphrase-multilingual-MiniLM-L12-v2 без нормализации
idx_3, emb_3, model_3 = build_faiss_index(model_name="paraphrase-multilingual-MiniLM-L12-v2", normalize=False)
emb_3.shape
# Out:
# modules.json:   0%|          | 0.00/229 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/122 [00:00<?, ?B/s]
# README.md: 0.00B [00:00, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/645 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/471M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/480 [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/9.08M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/239 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
# (44727, 384)

# %%
serch_list, gen_list = [], []
for i in inp:
  df_serch, gen_rag = generate_description_rag(i, idx_3, model_3, normalize=False, k=3)
  serch_list.append(df_serch['input'].tolist())
  gen_list.append(gen_rag)
df_sample['l12_k'] = serch_list
df_sample['l12_gen'] = gen_list

# %%
# paraphrase-multilingual-MiniLM-L12-v2 с нормализацией
idx_4, emb_4, model_4 = build_faiss_index(model_name="paraphrase-multilingual-MiniLM-L12-v2", normalize=True)
emb_4.shape
# Out:
# (44727, 384)

# %%
serch_list, gen_list = [], []
for i in inp:
  df_serch, gen_rag = generate_description_rag(i, idx_4, model_4, normalize=True, k=3)
  serch_list.append(df_serch['input'].tolist())
  gen_list.append(gen_rag)
df_sample['l12_norm_k'] = serch_list
df_sample['l12_norm_gen'] = gen_list

# %%
for _, row in df_sample.iterrows():
  print(f"Input text:\n{row['input']}\n")
  print(f"True target:\n{row['final_desc']}\n")
  print(f"all-MiniLM-L6-v2:\n{row['l6_gen']}\n")
  print(f"all-MiniLM-L6-v2 normalized:\n{row['l6_norm_gen']}\n")
  print(f"paraphrase-multilingual-MiniLM-L12-v2:\n{row['l12_gen']}\n")
  print(f"paraphrase-multilingual-MiniLM-L12-v2 normalized:\n{row['l12_norm_gen']}\n")
# Out:
# Input text:
# Наименование товара: Брюки классические прямые
# Сезон: круглогодичный
# Особенности модели: дышащий материал; немнущийся материал; эластичный материал
# Тип посадки: средняя
# Страна производства: Турция
# Вид застежки: молния
# Тип карманов: прорезные; косые
# Комплектация: брюки - 1 шт.
# Декоративные элементы: без стрелок
#
# True target:
# Брюки мужские классические демисезонные. Осенние костюмные брюки поразят вас своеи универсальностью, ведь они почти не мнутся и требуют минимального дополнительного ежедневного ухода. Такие повседневные штаны подходят для парнеи и мужчин, позволят быть одновременно стильными и брутальными. Прямые брюки без стрелок идеальны как праздничные для похода на свадьбу или юбилеи и как деловые для похода в офис на работу. Черные брюки будут оценены школьниками и студентами. Даже если раньше вы не носили классику в школу или универ, то сеичас не сможете устоять. Наши всесезонные брюки немного тянутся, имеют передние косые и задние прорезные карманы. Вечерние брюки стреич очень удобные и именно комфорт сделал этот фасон любимым у молодежи. Темная базовая одежда изготовлена в Турции из мягкого хлопка, вискозы и лаикры. Наши брюки предлагаются в больших размерах и подоидут для крупных парнеи и мужчин высокого или среднего роста
#
# all-MiniLM-L6-v2:
# Брюки классические прямые - это универсальная модель, которая идеально подойдет для создания строгих бизнес образов или же для создания повседневных стильных комбинаций. Изготовленные из дышащего, немнущегося и эластичного материала, эти брюки обеспечивают комфорт и свободу движений на протяжении всего дня. Средняя посадка гарантирует удобство носки, а прорезные и косые карманы добавляют функциональности.
# Брюки выполнены в классическом стиле без стрелок, что делает их универсальными и подходящими для любого случая. Застежка-молния обеспечивает практичность и удобство использования. Произведены в Турции, эти брюки отличаются высоким качеством исполнения и долговечностью. В комплекте идут только брюки, что позволяет вам самостоятельно подбирать сочетающуюся одежду и аксессуары. Благодаря своим универсальным характеристикам, эти брюки станут незаменимым элементом гардероба каждого мужчины.
#
# all-MiniLM-L6-v2 normalized:
# Классические прямые брюки из дышащего материала - отличный выбор для любого времени года. Благодаря эластичности ткани, брюки идеально садятся по фигуре, обеспечивая комфорт в течение всего дня. Материал не мнется, что позволяет выглядеть аккуратно и стильно вне зависимости от обстоятельств.
#
# Брюки выполнены в средней посадке, что делает их универсальным вариантом для любого типа фигуры. Прямой крой подчеркивает стройность ног, а декоративные элементы в виде прорезных и косых карманов добавляют удобства в повседневном использовании.
#
# Брюки классические прямые изготовлены в Турции и отличаются высоким качеством исполнения. Застежка в виде молнии удобна и практична в использовании. Брюки без стрелок идеально подходят для создания строгого делового образа или расслабленного кэжуал-стиля.
#
# Добавьте эти универсальные брюки в свой гардероб, и вы всегда будете выглядеть стильно и уверенно.
#
# paraphrase-multilingual-MiniLM-L12-v2:
# Брюки классического кроя выполнены из дышащего, немнущегося и эластичного материала, что обеспечивает комфорт в течение всего дня. Модель с прямым кроем и средней посадкой позволяет подчеркнуть достоинства фигуры, сохраняя при этом свободу движений. Брюки оснащены прорезными и косыми карманами, которые придают изделию практичность. Вид застежки - молния, что делает брюки удобными и функциональными в использовании. Благодаря отсутствию стрелок, модель выглядит аккуратной и стильной, идеально вписывается в деловой или повседневный гардероб. Брюки произведены в Турции, что гарантирует высокое качество и продолжительный срок службы изделия.
#
# paraphrase-multilingual-MiniLM-L12-v2 normalized:
# Брюки прямого кроя выполнены из дышащего, немнущегося и эластичного материала, что обеспечивает комфорт при носке. Средняя посадка подчеркнет вашу фигуру и обеспечит свободу движений. Практические прорезные и косые карманы добавят удобства в использовании. Застежка на молнию надежна и проста в использовании. Брюки без стрелок подойдут как для офиса, так и для повседневной носки. Изготовлены в Турции, что говорит о высоком качестве изделия. Эти брюки станут отличным дополнением к вашему гардеробу и подойдут на любой сезон.
#
# Input text:
# Наименование товара: Футболка унисекс новогодняя с принтом гринч
# Особенности модели: винтаж футболка новогодняя
# Декоративные элементы: новогодний принт дизайн рождественский
# Вырез горловины: округлый классический округленный
# Покрой: оверсайз oversize свободная удлиненная длинная широкая стандартная базовая
#
# True target:
# Новогодняя футболка оверсаиз с коротким рукавом: идеальныи подарок на Новыи год или рождество.
# Если вы ищете универсальныи и стильныи подарок на Новыи год, удлиненная футболка оверсаиз от WORLD DESIGN станет превосходным выбором. Эта футболка прекрасно подходит как для повседневнои носки, так и для активного отдыха. Ее свободныи крои и мягкии материал даст максимальныи комфорт.
# Эта футболка станет отличнои идееи подарка на Новыи год для девушки, жены, мамы, папы, дедушки, бабушки, подруги, коллеги или девочки. Универсальныи фасон позволяет создавать парные образы, что делает ее идеальным вариантом для пары, как парная футболка.
# Универсальныи дизаин: Белая и черная футболка с коротким рукавом и модели с оригинальными принтами легко сочетаются с другими элементами гардероба и подходят для любого случая, празднование Рождества и Нового года. Это идеальныи вариант для создания новогоднего образа или подарка.
# Футболка Изготовлена из плотного 100% хлопка, которыи приятен на коже, дышащии и сохраняет форму даже после множества стирок. Новогодние товары делают футболку идеальнои для частого использования и подарка.
# OVERSIZE крои: Свободныи крои обеспечивает комфорт, подходит для занятии спортом, иоги, танцев и повседневнои носки. Эта модель подоидет для полных и худых, высоких и невысоких женщин, обеспечивая стильныи вид.
# Независимо от того, выберете ли вы однотонную модель или футболку с принтом, это будет отличныи подарок на Рождество или символ года. Футболка оверсаиз подоидет для всех сезонов будь то лето, весна, осень или зима, добавляя уют и стиль в любои образ. Она станет базовои вещью гардероба, которая легко сочетается с любым гардеробом.
# Сделаите Новыи год особенным, подарив комфорт и стиль своим близким. Футболка для новогоднеи фотосессии станет практичным и модным дополнением к гардеробу и отличным новогодним подарком, которыи принесет радость и уют.
#
# all-MiniLM-L6-v2:
# Универсальная новогодняя футболка оверсайз с принтом гринч - это идеальный подарок для любителей праздничной атмосферы и веселых принтов. Свободный, удлиненный крой подойдет как мужчинам, так и женщинам, обеспечивая комфорт и свободу движений.
#
# Футболка выполнена в классическом стиле с округлым вырезом горловины. Она отлично сочетается с любыми элементами гардероба, будь то джинсы или брюки. Новогодний принт с изображением Гринча придаст вашему образу праздничного настроения и оригинальности.
#
# Модель выполнена из качественного материала, который обеспечивает долговечность и удобство носки. Такая футболка станет отличным выбором для новогодней вечеринки или семейного ужина.
#
# Винтажный стиль делает эту футболку особенной, она будет выглядеть стильно и модно даже спустя годы. Независимо от того, какой у вас стиль одежды, эта футболка станет универсальным решением для создания яркого и запоминающегося образа.
#
# Подарите себе и своим близким праздничное настроение с этой великолепной футболкой!
#
# all-MiniLM-L6-v2 normalized:
# Новогодняя футболка унисекс с принтом гринч отличный выбор для тех, кто ценит комфорт и оригинальность. Данная модель выполнена в стиле оверсайз, что подчеркивает ее свободу и непринужденность. Удлиненная, широкая и базовая, эта футболка подойдет как мужчинам, так и женщинам.
#
# Особенностью этой модели является новогодний принт с изображением гринча. Он придает футболке веселый и праздничный вид, делая ее идеальным выбором для новогодней вечеринки или уютного домашнего празднования.
#
# Футболка выполнена из качественного материала, который обеспечивает комфорт в носке и сохраняет свою форму после многократных стирок. Округлый классический вырез горловины дополняет общий стиль и делает модель универсальной.
#
# Эта новогодняя футболка с принтом гринча - это не только стильная и удобная одежда, но и отличный подарок на предстоящие праздники. Она подчеркнет ваше чувство стиля и любовь к новогодним традициям. Футболка доступна в различных размерах, поэтому вы без труда сможете подобрать идеальный вариант для себя или в подарок близкому человеку.
#
# paraphrase-multilingual-MiniLM-L12-v2:
# Новогодняя футболка унисекс оверсайз с принтом Гринч - это идеальный подарок на Новый год для любителей классических рождественских мультфильмов. Удлиненная футболка в винтажном стиле выполнена из качественного хлопка, который приятен на ощупь и сохраняет форму даже после многих стирок.
#
# Оригинальный новогодний дизайн с изображением Гринча создает атмосферу праздника и поднимает настроение. Округлый вырез горловины и свободный покрой обеспечивают комфорт во время носки. Футболка идеально сочетается с любыми элементами гардероба и подойдет как для праздничных мероприятий, так и для повседневного использования.
#
# Эта футболка - отличный выбор для тех, кто ценит комфорт и стиль. Она подойдет для любого возраста и пола, благодаря универсальному дизайну и свободному крою. Эта футболка станет отличным подарком для друзей, коллег, близких и родных на Новый год.
#
# Футболка унисекс новогодняя с принтом Гринч - это не только стильная и качественная одежда, но и возможность привнести в свой образ часть праздничного настроения и духа Рождества.
#
# paraphrase-multilingual-MiniLM-L12-v2 normalized:
# Новогодняя унисекс футболка оверсайз с принтом Гринч - идеальный подарок для любителей праздничной атмосферы. Винтажный стиль и оригинальный рождественский дизайн делают эту модель незаменимой в гардеробе каждого, кто хочет выделиться и создать неповторимый образ на новогодней вечеринке.
#
# Футболка выполнена из 100% хлопка, обеспечивающего комфортное ношение и сохранение формы даже после многочисленных стирок. Оверсайз покрой делает футболку идеальной для любого типа фигуры, обеспечивая свободу движений и уют.
#
# Округлый классический вырез подчеркивает линию шеи и добавляет модели элегантности. Принт с изображением Гринча, символизирующего наступление зимних праздников, дополняет общий стиль футболки и создает праздничное настроение.
#
# Эта футболка станет отличным подарком на Новый год для друзей, родных или коллег. Она подойдет как для мужчин, так и для женщин благодаря универсальному покрою и дизайну. Вы можете носить ее с джинсами, юбками или брюками, создавая каждый раз новый и стильный образ.
#
# Сделайте Новый год незабываемым, подарив себе и близким настоящую праздничную атмосфер
#
# Input text:
# Наименование товара: Пуховик зимний короткий с капюшоном
# Утеплитель: био-пух синтетический
# Температурный режим: до -30 градусов
# Плотность синтетического утеплителя: 300 г/кв.м
# Страна производства: Китай
# Вид застежки: молния
# Особенности модели: влаго и ветром защита
# Опции капюшона: съемный капюшон на кнопках
# Опции опушки: без опушки
# Тип карманов: прорезные
# Комплектация: Пуховик - 1шт.
# Покрой: прямой
#
# True target:
# Пуховик зимнии короткии с капюшоном от бренда. Фирменная цветовая гамма, обилие внешних и внутренних карманов. Высокое качество утеплителя, наполнение в 250гм позволяет выдерживать температуры до - 30 градусов. Рукава оснащены трикотажными манжетами, а высокии воротник стоика защищает шею. Подходит для использования как куртка зимняя. Легкии, теплыи, станет отличным подарком для мальчика, мужчины или подростка. В этом сезоне более 20 новых моделеи представленны в магазине продавца. Фабричныи Китаи. Обращаем ваше внимание: размерная сетка смещена на 1 размер, т.е. 46 размер изделия соответсвует 48 россиискому размеру. Для вашего удобства на саите и на этикетке указаны размеры с учетом этого смещения, т.е. размерная сетка изделия 46 - 54 перемаркирована в 48 - 56.
#
# all-MiniLM-L6-v2:
# Зимний короткий пуховик с капюшоном, произведенный в Китае, идеально подходит для суровых зимних условий. Утеплитель из синтетического био-пуха плотностью 300 г/кв.м обеспечивает высокую степень теплоизоляции, позволяя комфортно чувствовать себя при температуре до -30 градусов. Дополнительную защиту от непогоды обеспечивает ветро- и влагозащитная ткань верха пуховика.
#
# Модель имеет прямой покрой, что позволяет ей универсально подходить любому типу фигуры. Верхнюю часть украшает съемный капюшон, который легко и быстро крепится на кнопках. Капюшон без опушки, что придает ему строгий и лаконичный вид.
#
# Застежка-молния обеспечивает быстрое и удобное надевание и снимание пуховика. Прорезные карманы позволяют удобно разместить вещи и защитить руки от холода.
#
# Комплектация включает в себя один пуховик. Этот зимний короткий пуховик с капюшоном - отличный выбор для тех, кто ценит комфорт, тепло и стиль в одном флаконе.
#
# all-MiniLM-L6-v2 normalized:
# Этот короткий зимний пуховик с капюшоном, произведенный в Китае, идеально подойдет для холодной погоды благодаря своему утеплителю из био-пуха синтетического типа. Плотность утеплителя составляет 300 г/кв.м, что позволяет ему выдерживать температуры до -30 градусов. Удобная застежка-молния обеспечивает легкость надевания и снятия пуховика.
#
# Пуховик оснащен съемным капюшоном на кнопках, что увеличивает его функциональность и позволяет адаптировать его под разные погодные условия. Прорезные карманы предоставляют достаточно пространства для хранения ваших мелких вещей. Покрой пуховика прямой, что делает его универсальным и подходящим для любого типа фигуры.
#
# Этот пуховик особенно выделяется своими функциями защиты от влаги и ветра, делая его идеальным выбором для зимнего сезона. Он выполнен без декоративных элементов и опушки, что придает ему строгий и лаконичный вид. В комплект поставки входит один пуховик.
#
# paraphrase-multilingual-MiniLM-L12-v2:
# Короткий зимний пуховик с капюшоном - идеальное решение для тех, кто ценит комфорт и тепло. Утеплитель из био-пуха с плотностью 300 г/кв.м обеспечивает надежную защиту от морозов до -30 градусов. Модель выполнена в прямом покрое и оснащена съемным капюшоном на кнопках, который при необходимости можно легко отстегнуть. Застежка-молния надежно защищает от проникновения ветра, а влагозащитные свойства материала не позволят промокнуть даже в снежную погоду. Прорезные карманы обеспечат удобство использования и дополнительную защиту для рук от холода. Продукт произведен в Китае и подчеркивает стремление к качеству и комфорту. Комплектация включает в себя один пуховик.
#
# paraphrase-multilingual-MiniLM-L12-v2 normalized:
# Короткий зимний пуховик с капюшоном - это идеальный выбор для тех, кто ценит комфорт и тепло в холодное время года. Утеплитель из био-пуха с плотностью 300 г/кв.м обеспечивает отличную теплоизоляцию и защиту от мороза до -30 градусов. Водо- и ветрозащитные свойства делают этот пуховик незаменимым в зимний период. Удобная застежка на молнию позволяет быстро и легко надевать и снимать пуховик. Капюшон, которым оснащена модель, можно легко снять при помощи кнопок. Без опушки, капюшон обеспечивает дополнительную защиту от ветра и снега. Прорезные карманы предоставляют достаточно места для хранения мелких предметов. Пуховик имеет прямой покрой, который подходит практически для любого типа фигуры. Пуховик произведен в Китае, что гарантирует высокое качество изделия. В комплект входит один пуховик.
#
# Input text:
# Наименование товара: Праздничное платье рубашка на Новый год приталенное
# Вид застежки: пуговицы
# Страна производства: Россия
# Декоративные элементы: кружево
# Тип карманов: без карманов
# Тип рукава: длинные
# Вырез горловины: воротник-стойка
# Покрой: приталенный
# Комплектация: Брендовый пакет - 1 шт; Ажурное платье - 1 шт
#
# True target:
# Короткое вечернее платье - рубашка с необычными кружевными вставками. Модель платья - свободная расклешенная юбка мини, которая идеально сидит по фигуре, и нарядная рубашка с широкими длинными рукавами и модным воротничком стоикои без выреза. Напоминает трагичныи винтажныи стиль - подчеркивает талию, но в тоже время может скрыть небольшои животик беременнои девушки. Супер удобныи наряд в беременность или для невысоких эффектных женщин больших размеров с шикарными формами. Подоидет и строиным девочкам подросткам. Так как рубаха легко застегивается на пуговицы понравится молодым кормящим мамам. Есть удобныи доступ к груди вовремя весеннеи или осеннеи прогулки с новорожденным. В ажурном платье не только для кормления можно отправится куда угодно, особенно туда, где соблюдают строгии и официальныи деловои дресс код: на учебу, в университет, в офис, в колледж. Платье - рубаха с объемным кружевом - классика, приталенное, легкое, милое, нежное. Можно надеть как на торжество, так и на важное мероприятие: девичник невесты, свадьбу подружки, корпоратив на Новыи год, Halloween. Наденьте его на вечеринку в честь юбилея или на выпускнои в школу. Такая универсальная одежда просто находка как на каждыи день в демисезон, так и на торжественныи выход, вечер с друзьями или Нг вечеринку с коктеилями. Подоидет для осени на выписку из роддома. Ведь день рождение малыша - большои праздник. Полныи образ в нем может выглядеть как клубныи, молодежныи, подростковыи прикид, так и очень красивыи, женственныи, офисныи, элегантныи наряд. Стильная закрытая рубашка - платье а силуэта - универсальная повседневная вещь в женском гардеробе. Оно подоидет как для учителя, так и просто для летнего свидания в ресторане или новогоднеи, рождественскои, готическои фотосессии. Идеальное на крестины. Альтернатива красивым платьишкам для клуба и дискотеки в стиле Уэнсдеи, коктеильным, Лолита. Крои винтаж выполнен в классических базовых цветах весны, светлых лета, ярко темных зимы.
#
# all-MiniLM-L6-v2:
# Это платье рубашка на Новый год - приталенное, элегантное и изысканное. Оно выполнено из премиум-материалов и украшено кружевом, что добавляет в образ романтичности и женственности. Платье имеет длинные рукава, застежку на пуговицы и воротник-стойка, что придает ему официальный и аккуратный вид. Крой платья подчеркнет все достоинства вашей фигуры, а качественные материалы обеспечат комфорт в течение всего дня. Это идеальный выбор для праздничных мероприятий и торжественных событий. Платье выполнено в России, что гарантирует его высокое качество и долговечность. В комплект поставки входит брендовый пакет, что делает его отличным вариантом для подарка. Платье без карманов, что подчеркивает его элегантность и изящество. Оно легко сочетается с различными аксессуарами, так что вы можете создать множество уникальных образов.
#
# all-MiniLM-L6-v2 normalized:
# Праздничное платье-рубашка приталенного кроя - отличный выбор для новогодней вечеринки. Модель выполнена из высококачественного материала, который отличается эластичностью и прочностью. Платье декорировано изящным кружевом, что придает образу особую женственность и романтичность. Воротник-стойка и длинные рукава придают модели строгость и деловитость, при этом сохраняя ее праздничность. Застежка на пуговицы позволяет легко и быстро надевать и снимать изделие. Платье без карманов, что подчеркивает его элегантность и изящность. Приталенный крой модели подчеркивает фигуру и делает акцент на талии. Платье прилагается в брендовом пакете, что подчеркивает его премиальность и уникальность. С таким платьем вы будете в центре внимания на любом празднике!
#
# paraphrase-multilingual-MiniLM-L12-v2:
# Праздничное платье-рубашка на Новый год - это настоящая находка для модниц, которые ценят комфорт и стиль. Модель выполнена в приталенном покрое, что подчеркивает достоинства фигуры и скрывает ее недостатки. Российское производство гарантирует высокое качество изделия. Длинные рукава и воротник-стойка придают изделию строгость и элегантность. Декоративные кружевные элементы добавляют платью романтичности и нежности. Платье застегивается на пуговицы, что делает его удобным в носке. В комплект входит ажурное платье и брендовый пакет. Это платье будет отличным выбором для праздничного вечера, встречи Нового года или любого другого торжественного мероприятия.
#
# paraphrase-multilingual-MiniLM-L12-v2 normalized:
# Это праздничное платье-рубашка приталенного покроя отечественного производства - идеальный выбор для торжественных случаев. Оно выполнено в классическом стиле, с длинными рукавами и воротником-стойкой. Застежка на пуговицы обеспечивает удобство надевания и снимания платья. Декоративные элементы из кружева придают образу особую изысканность и элегантность. Платье без карманов, что делает его силуэт более стройным и изящным. Данная модель подчеркнет все достоинства вашей фигуры, а высококачественные материалы обеспечат комфорт в носке. Платье идеально подойдет для Новогоднего праздника, делая ваш образ незабываемым. В комплект поставки входят: ажурное платье и брендовый пакет.
#
# Input text:
# Наименование товара: Юбка атласная шелковая трапеция макси
# Вид застежки: резинка; без застежки
# Модель юбки: трапеция
# Декоративные элементы: без элементов
# Покрой: А-силуэт
#
# True target:
# Юбка женская макси атласная на резинке стильныи и универсальныи элемент женскои одежды, которыи станет основои для многих Ваших модных образов и придаст ему женственности и элегантности. Это идеальныи выбор для девушек, ценящих комфорт и стиль. Тренд лета для женщин.
# Длинныи крои делает ее подходящеи для различных событии как для повседневного наряда, так и для особых случаев. Изделие сшито по косои с высокои талиеи. Резинка в поясе обеспечивает идеальную посадку и комфорт при ношении, не стесняя движении. Наша коллекция моделеи разнообразна по размерам, идеально подходит как для высоких, так и для невысоких девушек. Она выгодно подчеркивает силуэт, придавая фигуре изящность. Благодаря широкому размерному ряду каждая женщина наидет подходящии для себя вариант. Наши изделия удобны для беременных и женщин больших размеров плюс саиз, так как их рекомендуется надевать и снимать через верх. Изготовленная из премиального искусственного шелка, юбка отличается блестящеи и легкои струящеися текстурои, которая придает еи праздничныи вид. Шелковая юбка легко сочетается с различными элементами гардероба и обувью. Сочетаите ее с облегающим топом для женственного и сексуального образа на вечернии выход. Черная или бежевая модель станет отличным вариантом для офиса. Добавьте к образу классическую блузку, жакет и туфли на небольшом каблуке для создания офисного и женственного образа. Вы также можете носить сатиновую прямую юбку и в повседневнои жизни. Комбинируите ее с футболкои, курткои и кедами для создания непринужденного и стильного образа на прогулку или встречу с друзьями. Нарядная юбка в пол также подоидет в качестве образа на свадьбу, на выпускнои в школу или последнии звонок для девочки подростка.
# В нашем ассортименте также представлены юбки длины миди, а также летние модели с разрезом.
#
# all-MiniLM-L6-v2:
# Шелковая юбка трапеция макси – это воплощение женственности и элегантности. Эта модель выполнена из высококачественного атласа, который обеспечивает комфортное ношение и привлекательный внешний вид. Силуэт А-линии и длина макси визуально вытягивают фигуру, делая образ более стройным и грациозным. Юбка не имеет декоративных элементов, что позволяет сочетать ее с различными топами и аксессуарами.
#
# Застежка на резинке и без застежки обеспечивает надежную и удобную посадку на талии. В такой юбке вы всегда будете чувствовать себя свободно и комфортно. Благодаря универсальности дизайна, юбка подойдет как для офиса, так и для прогулок или светских мероприятий.
#
# Модель юбки трапеция выглядит очень стильно и модно, а атласная ткань добавляет изделию изысканности и шика. Эта юбка - идеальный выбор для тех, кто ценит качество, комфорт и стиль в одежде. Вы можете сочетать ее с различными блузами, топами, свитерами, создавая уникальные и запоминающиеся образы.
#
# Юбка атласная шелковая трапеция макси - это настоящий маст-хэв в гардеробе каждой модницы. Она подчеркнет вашу индивидуальность
#
# all-MiniLM-L6-v2 normalized:
# Эта женская юбка макси на резинке - отличный выбор для тех, кто ценит комфорт и стиль в одежде. Выполненная из атласного шелка, она представляет собой модель трапециевидного кроя, который благодаря своему А-силуэту подчеркивает женственность фигуры и придает ей изящность. Юбка выполнена в максимальной длине, что делает ее отличным вариантом для создания стильных и элегантных образов. Отсутствие застежки и наличие резинки на поясе обеспечивают идеальную посадку и комфорт при ношении. Юбка атласная шелковая трапеция макси без декоративных элементов, что позволяет ей легко сочетаться с различной верхней одеждой и аксессуарами. Эта модель будет отлично смотреться как с облегающими топами, так и с объемными свитерами или жакетами. Изделие из атласа дарит ощущение роскоши и комфорта, а шелковая ткань мягко облегает фигуру и хорошо держит форму. Эта юбка станет незаменимым элементом вашего гардероба на любое время года.
#
# paraphrase-multilingual-MiniLM-L12-v2:
# Шелковая атласная юбка макси - это универсальная деталь гардероба, которая подойдет для любого случая. Она выполнена из высококачественного шелка, который дарит нежный блеск и приятное тактильное ощущение. Модель юбки трапеция придает изделию изящный и женственный вид.
#
# Застежки отсутствуют, что обеспечивает максимальное удобство при надевании. Вместо застежки используется эластичная резинка, обеспечивающая комфортную посадку на любой тип фигуры. Благодаря покрою А-силуэт, юбка подчеркивает талию и скрывает недостатки фигуры, придавая образу изысканность и гармонию.
#
# Декоративные элементы в дизайне юбки отсутствуют, что позволяет сосредоточить внимание на качестве материала и утонченности кроя. Эта модель юбки станет отличным дополнением к вашему образу, будь то деловая встреча, романтическое свидание или повседневная прогулка.
#
# Атласная юбка в пол выполнена в нескольких цветовых вариациях и размерах, что позволит каждой женщине подобрать идеальный вариант для себя. Независимо от выбранного образа, эта юбка подчеркнет вашу индивидуальность и добавит изысканности в любой стиль.
#
# paraphrase-multilingual-MiniLM-L12-v2 normalized:
# Эффектная атласная юбка из шелка станет настоящим украшением вашего гардероба. Эта модель выполнена в стиле "трапеция", что придает изделию особую элегантность и женственность. Покрой "А-силуэт" идеально подчеркивает талию и скрывает возможные недостатки фигуры.
#
# Юбка изготовлена из атласного шелка, который не только красиво смотрится, но и приятен к телу. Благодаря своей длине, она идеально подойдет как для повседневной носки, так и для особого случая.
#
# Без застежки, за счет удобной резинки на талии, эта юбка просто и легко надевается. Без декоративных элементов, она выглядит строго и элегантно.
#
# Это изделие станет незаменимым элементом вашего гардероба, ведь его можно сочетать с различными элементами одежды. Юбка атласная шелковая трапеция макси подойдет как для офиса, так и для вечернего выхода.

# %% [markdown]
# В целом качество генерации для всех конфигураций довольно приличное. Серьезные галлюцинации практически отсутсвуют.
# Иногда проскакивают мелкие галлюцинации — например:
# - выдумывает состав: «100% хлопок», «натуральный шелк»
# - приписывает качества: «премиум-материалы», «долговечность», «сохраняет форму»
#
# Нормализованные модели дают более шаблонный и менее детализированный текст
# Ненормализованные модели дают больше конкретики, тексты ближе по стилю к таргету
#
#
# Теперь посмотрим на релевантность близжайших примеров

# %%
for _, row in df_sample.iterrows():
  print(f"Input text:\n{row['input']}\n")
  print(f"all-MiniLM-L6-v2:\n{row['l6_k']}\n")
  print(f"all-MiniLM-L6-v2 normalized:\n{row['l6_norm_k']}\n")
  print(f"paraphrase-multilingual-MiniLM-L12-v2:\n{row['l12_k']}\n")
  print(f"paraphrase-multilingual-MiniLM-L12-v2 normalized:\n{row['l12_norm_k']}\n")
# Out:
# Input text:
# Наименование товара: Брюки классические прямые
# Сезон: круглогодичный
# Особенности модели: дышащий материал; немнущийся материал; эластичный материал
# Тип посадки: средняя
# Страна производства: Турция
# Вид застежки: молния
# Тип карманов: прорезные; косые
# Комплектация: брюки - 1 шт.
# Декоративные элементы: без стрелок
#
# all-MiniLM-L6-v2:
# ['Наименование товара: Брюки классические зауженные\nСезон: круглогодичный\nОсобенности модели: дышащий материал\nТип посадки: средняя\nСтрана производства: Китай\nВид застежки: пуговицы; молния\nТип карманов: прорезные\nКомплектация: брюки мужские - 1 шт\nДекоративные элементы: без элементов', 'Наименование товара: Брюки мужские утепленные оверсайз спортивные\nСезон: круглогодичный\nОсобенности модели: дышащий материал; утепленные; с начесом\nТип посадки: средняя\nСтрана производства: Узбекистан\nВид застежки: завязки; шнуровка\nТип карманов: прорезные\nКомплектация: Брюки - 1 шт.\nДекоративные элементы: без элементов; молния; вышивка', 'Наименование товара: Брюки бананы укороченные классические\nСезон: демисезон\nОсобенности модели: дышащий материал; немнущаяся ткань; свободный крой\nТип посадки: высокая\nСтрана производства: Киргизия\nВид застежки: молния; пуговицы\nТип карманов: прорезные\nКомплектация: брюки - 1 шт\nДекоративные элементы: молния; пуговицы']
#
# all-MiniLM-L6-v2 normalized:
# ['Наименование товара: Брюки классические зауженные\nСезон: круглогодичный\nОсобенности модели: дышащий материал\nТип посадки: средняя\nСтрана производства: Китай\nВид застежки: пуговицы; молния\nТип карманов: прорезные\nКомплектация: брюки мужские - 1 шт\nДекоративные элементы: без элементов', 'Наименование товара: Брюки мужские утепленные оверсайз спортивные\nСезон: круглогодичный\nОсобенности модели: дышащий материал; утепленные; с начесом\nТип посадки: средняя\nСтрана производства: Узбекистан\nВид застежки: завязки; шнуровка\nТип карманов: прорезные\nКомплектация: Брюки - 1 шт.\nДекоративные элементы: без элементов; молния; вышивка', 'Наименование товара: Брюки бананы укороченные классические\nСезон: демисезон\nОсобенности модели: дышащий материал; немнущаяся ткань; свободный крой\nТип посадки: высокая\nСтрана производства: Киргизия\nВид застежки: молния; пуговицы\nТип карманов: прорезные\nКомплектация: брюки - 1 шт\nДекоративные элементы: молния; пуговицы']
#
# paraphrase-multilingual-MiniLM-L12-v2:
# ['Наименование товара: Брюки классические прямые\nСезон: круглогодичный\nОсобенности модели: дышащий материал\nТип посадки: средняя\nСтрана производства: Турция\nВид застежки: молния; завязки\nТип карманов: прорезные\nКомплектация: брюки', 'Наименование товара: Брюки чинос узкие\nСезон: круглогодичный\nОсобенности модели: дышащий материал\nТип посадки: средняя\nСтрана производства: Турция\nВид застежки: молния; завязки\nТип карманов: прорезные\nКомплектация: Брюки мужские демисезонные - 1 шт\nДекоративные элементы: штаны классика', 'Наименование товара: Брюки прямые чинос летние\nСезон: круглогодичный\nОсобенности модели: дышащий материал\nТип посадки: средняя\nСтрана производства: Турция\nВид застежки: молния; пуговицы\nТип карманов: прорезные\nКомплектация: брюки мужские - 1 шт\nДекоративные элементы: без декоративных элементов']
#
# paraphrase-multilingual-MiniLM-L12-v2 normalized:
# ['Наименование товара: Брюки классические прямые\nСезон: круглогодичный\nОсобенности модели: дышащий материал\nТип посадки: средняя\nСтрана производства: Турция\nВид застежки: молния; завязки\nТип карманов: прорезные\nКомплектация: брюки', 'Наименование товара: Брюки чинос узкие\nСезон: круглогодичный\nОсобенности модели: дышащий материал\nТип посадки: средняя\nСтрана производства: Турция\nВид застежки: молния; завязки\nТип карманов: прорезные\nКомплектация: Брюки мужские демисезонные - 1 шт\nДекоративные элементы: штаны классика', 'Наименование товара: Брюки прямые чинос летние\nСезон: круглогодичный\nОсобенности модели: дышащий материал\nТип посадки: средняя\nСтрана производства: Турция\nВид застежки: молния; пуговицы\nТип карманов: прорезные\nКомплектация: брюки мужские - 1 шт\nДекоративные элементы: без декоративных элементов']
#
# Input text:
# Наименование товара: Футболка унисекс новогодняя с принтом гринч
# Особенности модели: винтаж футболка новогодняя
# Декоративные элементы: новогодний принт дизайн рождественский
# Вырез горловины: округлый классический округленный
# Покрой: оверсайз oversize свободная удлиненная длинная широкая стандартная базовая
#
# all-MiniLM-L6-v2:
# ['Наименование товара: Футболка новогодняя том и джерри\nОсобенности модели: винтаж футболка новогодняя\nДекоративные элементы: новогодний принт дизайн\nВырез горловины: округлый классический округленный\nПокрой: оверсайз oversize свободная удлиненная длинная широкая стандартная базовая', 'Наименование товара: Футболка мужская Рик и Морти женская с принтом оверсайз\nСтрана производства: Россия\nОсобенности модели: дышащий материал\nДекоративные элементы: без элементов\nТип карманов: без карманов\nВырез горловины: округлый\nПокрой: оверсайз oversize свободная удлиненная длинная широкая стандартная базовая\nКомплектация: Футболка с принтом - 1шт.', 'Наименование товара: Блузка нарядная с длинным рукавом для офиса и школы\nВид застежки: пуговицы\nОсобенности модели: дышащий материал\nСтрана производства: Россия\nПокрой: свободный\nДекоративные элементы: oversize; рукава с манжетом; кружево\nТип рукава: длинные\nВырез горловины: отложной воротник\nКомплектация: блузка 1 шт']
#
# all-MiniLM-L6-v2 normalized:
# ['Наименование товара: Футболка новогодняя том и джерри\nОсобенности модели: винтаж футболка новогодняя\nДекоративные элементы: новогодний принт дизайн\nВырез горловины: округлый классический округленный\nПокрой: оверсайз oversize свободная удлиненная длинная широкая стандартная базовая', 'Наименование товара: Футболка мужская Рик и Морти женская с принтом оверсайз\nСтрана производства: Россия\nОсобенности модели: дышащий материал\nДекоративные элементы: без элементов\nТип карманов: без карманов\nВырез горловины: округлый\nПокрой: оверсайз oversize свободная удлиненная длинная широкая стандартная базовая\nКомплектация: Футболка с принтом - 1шт.', 'Наименование товара: Блузка нарядная с длинным рукавом для офиса и школы\nВид застежки: пуговицы\nОсобенности модели: дышащий материал\nСтрана производства: Россия\nПокрой: свободный\nДекоративные элементы: oversize; рукава с манжетом; кружево\nТип рукава: длинные\nВырез горловины: отложной воротник\nКомплектация: блузка 1 шт']
#
# paraphrase-multilingual-MiniLM-L12-v2:
# ['Наименование товара: Футболка новогодняя том и джерри\nОсобенности модели: винтаж футболка новогодняя\nДекоративные элементы: новогодний принт дизайн\nВырез горловины: округлый классический округленный\nПокрой: оверсайз oversize свободная удлиненная длинная широкая стандартная базовая', 'Наименование товара: Футболка новогодняя том и джерри\nОсобенности модели: винтаж футболка новогодняя\nДекоративные элементы: новогодний принт дизайн\nВырез горловины: округлый классический округленный\nПокрой: оверсайз OVERSIZE', 'Наименование товара: Футболка новогодняя с Дедом Морозом\nДекоративные элементы: новогодний принт\nТип карманов: без карманов\nВырез горловины: Горловина округлой формы\nПокрой: Прямой свободный\nКомплектация: футболка с новым годом 1 шт.']
#
# paraphrase-multilingual-MiniLM-L12-v2 normalized:
# ['Наименование товара: Футболка новогодняя том и джерри\nОсобенности модели: винтаж футболка новогодняя\nДекоративные элементы: новогодний принт дизайн\nВырез горловины: округлый классический округленный\nПокрой: оверсайз oversize свободная удлиненная длинная широкая стандартная базовая', 'Наименование товара: Футболка новогодняя том и джерри\nОсобенности модели: винтаж футболка новогодняя\nДекоративные элементы: новогодний принт дизайн\nВырез горловины: округлый классический округленный\nПокрой: оверсайз OVERSIZE', 'Наименование товара: Футболка новогодняя с Дедом Морозом\nДекоративные элементы: новогодний принт\nТип карманов: без карманов\nВырез горловины: Горловина округлой формы\nПокрой: Прямой свободный\nКомплектация: футболка с новым годом 1 шт.']
#
# Input text:
# Наименование товара: Пуховик зимний короткий с капюшоном
# Утеплитель: био-пух синтетический
# Температурный режим: до -30 градусов
# Плотность синтетического утеплителя: 300 г/кв.м
# Страна производства: Китай
# Вид застежки: молния
# Особенности модели: влаго и ветром защита
# Опции капюшона: съемный капюшон на кнопках
# Опции опушки: без опушки
# Тип карманов: прорезные
# Комплектация: Пуховик - 1шт.
# Покрой: прямой
#
# all-MiniLM-L6-v2:
# ['Наименование товара: Пуховик зимний короткий с капюшоном\nУтеплитель: синтепух\nТемпературный режим: от -5 до -30\nПлотность синтетического утеплителя: 300 г/кв.м\nСтрана производства: Россия\nМатериал подкладки: поливискоза\nВид застежки: молния\nОсобенности модели: ветрозащита\nОпции капюшона: несъемный капюшон\nОпции опушки: без опушки\nДекоративные элементы: без элементов\nТип карманов: прорезные\nКомплектация: Пуховик - 1 шт.\nПокрой: оверсайз', 'Наименование товара: Пуховик зимний удлиненный с капюшоном\nУтеплитель: Био-Пух\nТемпературный режим: до -30 градусов\nПлотность синтетического утеплителя: 250 г/кв.м\nСтрана производства: Китай\nВид застежки: Молния, планка на пуговицах\nОсобенности модели: влаго и ветром защита\nОпции капюшона: съемный капюшон\nОпции опушки: без опушки\nТип карманов: прорезные\nКомплектация: Пуховик - 1 шт.\nПокрой: прямой', 'Наименование товара: Пуховик зимний с капюшоном длинный\nСезон: зима\nУтеплитель: био пух\nТемпературный режим: -25 -30 градусов\nПлотность синтетического утеплителя: 250 г/кв.м\nСтрана производства: Китай\nВид застежки: молния\nОсобенности модели: отстегивается капюшон\nОпции капюшона: съемный капюшон\nОпции опушки: без опушки\nДекоративные элементы: молния\nТип карманов: прорезные\nКомплектация: Пуховик мужской зимний длинный с капюшоном; пуховик мужской зимний; пуховик мужской\nПокрой: прямой']
#
# all-MiniLM-L6-v2 normalized:
# ['Наименование товара: Пуховик зимний короткий с капюшоном\nУтеплитель: синтепух\nТемпературный режим: от -5 до -30\nПлотность синтетического утеплителя: 300 г/кв.м\nСтрана производства: Россия\nМатериал подкладки: поливискоза\nВид застежки: молния\nОсобенности модели: ветрозащита\nОпции капюшона: несъемный капюшон\nОпции опушки: без опушки\nДекоративные элементы: без элементов\nТип карманов: прорезные\nКомплектация: Пуховик - 1 шт.\nПокрой: оверсайз', 'Наименование товара: Пуховик зимний удлиненный с капюшоном\nУтеплитель: Био-Пух\nТемпературный режим: до -30 градусов\nПлотность синтетического утеплителя: 250 г/кв.м\nСтрана производства: Китай\nВид застежки: Молния, планка на пуговицах\nОсобенности модели: влаго и ветром защита\nОпции капюшона: съемный капюшон\nОпции опушки: без опушки\nТип карманов: прорезные\nКомплектация: Пуховик - 1 шт.\nПокрой: прямой', 'Наименование товара: Пуховик зимний с капюшоном длинный\nСезон: зима\nУтеплитель: био пух\nТемпературный режим: -25 -30 градусов\nПлотность синтетического утеплителя: 250 г/кв.м\nСтрана производства: Китай\nВид застежки: молния\nОсобенности модели: отстегивается капюшон\nОпции капюшона: съемный капюшон\nОпции опушки: без опушки\nДекоративные элементы: молния\nТип карманов: прорезные\nКомплектация: Пуховик мужской зимний длинный с капюшоном; пуховик мужской зимний; пуховик мужской\nПокрой: прямой']
#
# paraphrase-multilingual-MiniLM-L12-v2:
# ['Наименование товара: Пуховик зимний удлиненный с капюшоном\nУтеплитель: Био-Пух\nТемпературный режим: до -30 градусов\nПлотность синтетического утеплителя: 250 г/кв.м\nСтрана производства: Китай\nВид застежки: Молния, планка на пуговицах\nОсобенности модели: влаго и ветром защита\nОпции капюшона: съемный капюшон\nОпции опушки: без опушки\nТип карманов: прорезные\nКомплектация: Пуховик - 1 шт.\nПокрой: прямой', 'Наименование товара: Пуховик зимний удлиненный с капюшоном куртка\nУтеплитель: Био-Пух\nТемпературный режим: от +10 до -30 °С\nПлотность синтетического утеплителя: 260 г/кв.м\nСтрана производства: Китай\nМатериал подкладки: полиэстер\nВид застежки: молния; кнопки\nОсобенности модели: классика\nОпции капюшона: съемный капюшон\nОпции опушки: без опушки\nДекоративные элементы: трикотажные манжеты, нагрудный карман, воротник стойка, кулиска\nТип карманов: прорезные\nКомплектация: Пуховик мужской зимний удлиненный с капюшоном - 1 шт.\nПокрой: прямой', 'Наименование товара: Пуховик зимний короткий куртка с капюшоном\nУтеплитель: Био-Пух\nТемпературный режим: от -10 °C до -20 °C\nПлотность синтетического утеплителя: 400 г/кв.м\nСтрана производства: Китай\nМатериал подкладки: 100% полиэстер\nВид застежки: молния; кнопки\nОсобенности модели: ветрозащита; влаговпитывающий материал\nОпции капюшона: несъемный капюшон\nОпции опушки: без опушки\nДекоративные элементы: карман на груди; молния; зимняя куртка женская\nТип карманов: прорезные\nКомплектация: пуховик 1 шт\nПокрой: прямой']
#
# paraphrase-multilingual-MiniLM-L12-v2 normalized:
# ['Наименование товара: Пуховик зимний удлиненный с капюшоном\nУтеплитель: Био-Пух\nТемпературный режим: до -30 градусов\nПлотность синтетического утеплителя: 250 г/кв.м\nСтрана производства: Китай\nВид застежки: Молния, планка на пуговицах\nОсобенности модели: влаго и ветром защита\nОпции капюшона: съемный капюшон\nОпции опушки: без опушки\nТип карманов: прорезные\nКомплектация: Пуховик - 1 шт.\nПокрой: прямой', 'Наименование товара: Пуховик зимний короткий куртка с капюшоном\nУтеплитель: Био-Пух\nТемпературный режим: от -10 °C до -20 °C\nПлотность синтетического утеплителя: 400 г/кв.м\nСтрана производства: Китай\nМатериал подкладки: 100% полиэстер\nВид застежки: молния; кнопки\nОсобенности модели: ветрозащита; влаговпитывающий материал\nОпции капюшона: несъемный капюшон\nОпции опушки: без опушки\nДекоративные элементы: карман на груди; молния; зимняя куртка женская\nТип карманов: прорезные\nКомплектация: пуховик 1 шт\nПокрой: прямой', 'Наименование товара: Пуховик зимний удлиненный с капюшоном куртка\nУтеплитель: Био-Пух\nТемпературный режим: от +10 до -30 °С\nПлотность синтетического утеплителя: 260 г/кв.м\nСтрана производства: Китай\nМатериал подкладки: полиэстер\nВид застежки: молния; кнопки\nОсобенности модели: классика\nОпции капюшона: съемный капюшон\nОпции опушки: без опушки\nДекоративные элементы: трикотажные манжеты, нагрудный карман, воротник стойка, кулиска\nТип карманов: прорезные\nКомплектация: Пуховик мужской зимний удлиненный с капюшоном - 1 шт.\nПокрой: прямой']
#
# Input text:
# Наименование товара: Праздничное платье рубашка на Новый год приталенное
# Вид застежки: пуговицы
# Страна производства: Россия
# Декоративные элементы: кружево
# Тип карманов: без карманов
# Тип рукава: длинные
# Вырез горловины: воротник-стойка
# Покрой: приталенный
# Комплектация: Брендовый пакет - 1 шт; Ажурное платье - 1 шт
#
# all-MiniLM-L6-v2:
# ['Наименование товара: Приталенная рубашка корсетного типа\nВид застежки: пуговицы\nОсобенности модели: Праздничная, базовая, повседневная, нарядная модель\nСтрана производства: Россия\nПокрой: приталенный\nДекоративные элементы: шнуровка; банты; пуговицы\nТип рукава: длинные\nВырез горловины: отложной воротник\nКомплектация: рубашка', 'Наименование товара: Туника вязаная больших размеров\nСтрана производства: Россия\nВид застежки: нет\nОсобенности модели: узор\nДекоративные элементы: карманы\nТип карманов: накладные\nТип рукава: длинные\nВырез горловины: округлый\nФактура материала: вязаный\nПокрой: полуприлегающий\nКомплектация: Джемпер - 1 шт.', 'Наименование товара: Пальто классическое демисезонное\nМатериал подкладки: вискоза\nСтрана производства: Россия\nВид застежки: пуговицы\nОсобенности модели: Стиль\nДекоративные элементы: шлица\nТип карманов: прорезные\nКонструктивные элементы: карман\nТип рукава: длинные\nКомплектация: Пояс - 1 шт.\nПокрой: приталенный']
#
# all-MiniLM-L6-v2 normalized:
# ['Наименование товара: Приталенная рубашка корсетного типа\nВид застежки: пуговицы\nОсобенности модели: Праздничная, базовая, повседневная, нарядная модель\nСтрана производства: Россия\nПокрой: приталенный\nДекоративные элементы: шнуровка; банты; пуговицы\nТип рукава: длинные\nВырез горловины: отложной воротник\nКомплектация: рубашка', 'Наименование товара: Туника вязаная больших размеров\nСтрана производства: Россия\nВид застежки: нет\nОсобенности модели: узор\nДекоративные элементы: карманы\nТип карманов: накладные\nТип рукава: длинные\nВырез горловины: округлый\nФактура материала: вязаный\nПокрой: полуприлегающий\nКомплектация: Джемпер - 1 шт.', 'Наименование товара: Пальто классическое демисезонное\nМатериал подкладки: вискоза\nСтрана производства: Россия\nВид застежки: пуговицы\nОсобенности модели: Стиль\nДекоративные элементы: шлица\nТип карманов: прорезные\nКонструктивные элементы: карман\nТип рукава: длинные\nКомплектация: Пояс - 1 шт.\nПокрой: приталенный']
#
# paraphrase-multilingual-MiniLM-L12-v2:
# ['Наименование товара: Праздничное платье рубашка новогоднее 2025\nМатериал подкладки: без подкладки\nВид застежки: пуговицы\nСтрана производства: Россия\nДекоративные элементы: кружево\nТип карманов: без карманов\nТип рукава: длинные\nВырез горловины: воротник-стойка\nПокрой: приталенный\nКомплектация: платье ажурное - 1 шт; Брендовый пакет - 1 шт', 'Наименование товара: Праздничное платье рубашка вечернее на осень\nВид застежки: пуговицы\nСтрана производства: Россия\nДекоративные элементы: кружево\nТип карманов: без карманов\nТип рукава: длинные\nВырез горловины: воротник-стойка\nПокрой: приталенный\nКомплектация: Брендовый пакет - 1 шт; платье ажурное - 1 шт', 'Наименование товара: Новогодний свитер платье оверсайз вязаный с оленями\nСтрана производства: Россия\nВид застежки: без застежки\nОсобенности модели: крупная вязка; family look; эластичный материал\nДекоративные элементы: вышивка\nТип карманов: без карманов\nТип рукава: длинные\nВырез горловины: круглый\nФактура материала: трикотажный\nПокрой: оверсайз\nКомплектация: туника-1шт']
#
# paraphrase-multilingual-MiniLM-L12-v2 normalized:
# ['Наименование товара: Праздничное платье рубашка новогоднее 2025\nМатериал подкладки: без подкладки\nВид застежки: пуговицы\nСтрана производства: Россия\nДекоративные элементы: кружево\nТип карманов: без карманов\nТип рукава: длинные\nВырез горловины: воротник-стойка\nПокрой: приталенный\nКомплектация: платье ажурное - 1 шт; Брендовый пакет - 1 шт', 'Наименование товара: Праздничное платье рубашка вечернее на осень\nВид застежки: пуговицы\nСтрана производства: Россия\nДекоративные элементы: кружево\nТип карманов: без карманов\nТип рукава: длинные\nВырез горловины: воротник-стойка\nПокрой: приталенный\nКомплектация: Брендовый пакет - 1 шт; платье ажурное - 1 шт', 'Наименование товара: Новогодний свитер платье оверсайз вязаный с оленями\nСтрана производства: Россия\nВид застежки: без застежки\nОсобенности модели: крупная вязка; family look; эластичный материал\nДекоративные элементы: вышивка\nТип карманов: без карманов\nТип рукава: длинные\nВырез горловины: круглый\nФактура материала: трикотажный\nПокрой: оверсайз\nКомплектация: туника-1шт']
#
# Input text:
# Наименование товара: Юбка атласная шелковая трапеция макси
# Вид застежки: резинка; без застежки
# Модель юбки: трапеция
# Декоративные элементы: без элементов
# Покрой: А-силуэт
#
# all-MiniLM-L6-v2:
# ['Наименование товара: Юбка атласная миди трапеция\nВид застежки: резинка; замок\nМодель юбки: трапеция\nДекоративные элементы: без элементов\nПокрой: А-силуэт', 'Наименование товара: Юбка атласная шелковая на резинке\nВид застежки: без застежки\nМодель юбки: трапеция\nДекоративные элементы: без элементов\nПокрой: А-силуэт', 'Наименование товара: Юбка атласная макси длинная\nСтрана производства: Россия\nВид застежки: резинка; без застежки\nМодель юбки: трапеция\nДекоративные элементы: без элементов\nПокрой: А-силуэт']
#
# all-MiniLM-L6-v2 normalized:
# ['Наименование товара: Юбка атласная миди трапеция\nВид застежки: резинка; замок\nМодель юбки: трапеция\nДекоративные элементы: без элементов\nПокрой: А-силуэт', 'Наименование товара: Юбка атласная шелковая на резинке\nВид застежки: без застежки\nМодель юбки: трапеция\nДекоративные элементы: без элементов\nПокрой: А-силуэт', 'Наименование товара: Юбка атласная макси длинная\nСтрана производства: Россия\nВид застежки: резинка; без застежки\nМодель юбки: трапеция\nДекоративные элементы: без элементов\nПокрой: А-силуэт']
#
# paraphrase-multilingual-MiniLM-L12-v2:
# ['Наименование товара: Юбка атласная из шелка\nВид застежки: без застежки\nМодель юбки: трапеция\nДекоративные элементы: без элементов\nПокрой: А-силуэт', 'Наименование товара: Юбка атласная шелковая на резинке\nВид застежки: без застежки\nМодель юбки: трапеция\nДекоративные элементы: без элементов\nПокрой: А-силуэт', 'Наименование товара: Юбка атласная шелковая трапеция плотная\nМодель юбки: трапеция\nДекоративные элементы: без элементов\nПокрой: А-силуэт']
#
# paraphrase-multilingual-MiniLM-L12-v2 normalized:
# ['Наименование товара: Юбка атласная из шелка\nВид застежки: без застежки\nМодель юбки: трапеция\nДекоративные элементы: без элементов\nПокрой: А-силуэт', 'Наименование товара: Юбка атласная шелковая на резинке\nВид застежки: без застежки\nМодель юбки: трапеция\nДекоративные элементы: без элементов\nПокрой: А-силуэт', 'Наименование товара: Юбка атласная шелковая трапеция плотная\nМодель юбки: трапеция\nДекоративные элементы: без элементов\nПокрой: А-силуэт']

# %% [markdown]
# Видно, что `paraphrase-multilingual-MiniLM-L12-v2` дает более релевантные примеры, чем `all-MiniLM-L6-v2`
#
# Например, для «Праздничное платье рубашка на Новый год приталенное» `all-MiniLM-L6-v2` выдает в качестве близжайших примеров:
#
# 1. Приталенная рубашка корсетного типа
# 2. Туника вязаная больших размеров
# 3. Пальто классическое демисезонное
#
# что не совсем релевантно для рассматриваемого примера
#
# Так как качество подобранных примеров определяет стабильность RAG, выбираю paraphrase-multilingual-MiniLM-L12-v2.
# Ненормализованная версия даёт более богатый и рекламный стиль описаний при сохранении приемлемой фактичности, поэтому выбираю paraphrase-multilingual-MiniLM-L12-v2 без нормализации.

# %%
# сохраняем индекс
faiss.write_index(idx_3, "drive/MyDrive/proj_cloth_desc_gen/final_idx.index")

# %%
# сохраняем эмбеддинги
df_embeddings = pd.DataFrame({
    "text": df_train["input"].tolist(),
    "embedding": [emb.tolist() for emb in emb_3],
    "final_desc": df_train["final_desc"].tolist(),
})
df_embeddings.to_parquet("drive/MyDrive/proj_cloth_desc_gen/embeddings.parquet")

# %% [markdown]
# ## 3. Генерация текста
# Беру сэмпл из 200 примеров из тестовой выборки. Для каждого примера генерирую описание и сохраняю результат в CSV.

# %%
index = faiss.read_index("drive/MyDrive/proj_cloth_desc_gen/final_idx.index")

# %%
df_test =  pd.read_csv('drive/MyDrive/proj_cloth_desc_gen/df_sample_pred.csv', index_col =0).reset_index(drop=True)
df_test["input"] = df_test["input"].str.replace("Сгенерируй описание одежды для карточки товара:\n", "", regex=False)

# %%
df_embeddings = pd.read_parquet("drive/MyDrive/proj_cloth_desc_gen/embeddings.parquet")
df_embeddings
# Out:
#                                                     text  \
# 0      Наименование товара: Костюм Деда Мороза\nОсобе...
# 1      Наименование товара: Куртка зимняя с капюшоном...
# 2      Наименование товара: Однотонная футболка поло ...
# 3      Наименование товара: Зимняя куртка (бушлат) ВК...
# 4      Наименование товара: Новогодняя футболка с над...
# ...                                                  ...
# 44722  Наименование товара: Топ бандо без лямок\nПокр...
# 44723  Наименование товара: Толстовка на молнии оверс...
# 44724  Наименование товара: Прозрачный лонгслив облег...
# 44725  Наименование товара: Свитер свободный с грибам...
# 44726  Наименование товара: Комбинезон из вискозы с р...
#
#                                                embedding  \
# 0      [-0.21763770282268524, 0.250986784696579, 0.06...
# 1      [-0.16727910935878754, 0.12410808354616165, 0....
# 2      [0.22782951593399048, 0.3239396810531616, -0.0...
# 3      [-0.18706287443637848, 0.22443805634975433, 0....
# 4      [-0.15429887175559998, 0.26661792397499084, -0...
# ...                                                  ...
# 44722  [-0.10823718458414078, 0.1371346116065979, 0.0...
# 44723  [-0.15855193138122559, 0.030281798914074898, 0...
# 44724  [-0.08728830516338348, 0.22507517039775848, 0....
# 44725  [-0.12986910343170166, 0.1911398321390152, 0.0...
# 44726  [-0.1579085886478424, 0.131863072514534, 0.002...
#
#                                               final_desc
# 0      Предлагаем вашему вниманию идеальныи мужскои в...
# 1      DESPORT это качественные и доступные спортивны...
# 2      Рубашка поло с коротким рукавом прямого кроя с...
# 3      Куртка зимняя ВКБОВКПО предназначена для испол...
# 4      Женская футболка от бренда со стразами это иде...
# ...                                                  ...
# 44722  Топ женскии бандо без чашек от бренда - это кл...
# 44723  Толстовка женская на молнии с принтом диснеи м...
# 44724  Полупрозрачныи лонгслив это отличныи выбор для...
# 44725  Свитер изготовлен в России, универсальныи свит...
# 44726  Полуприлегающии женскии комбинезон с короткими...
#
# [44727 rows x 3 columns]

# %%
model = SentenceTransformer("paraphrase-multilingual-MiniLM-L12-v2")

# %%
# функция поиска k ближайших примеров 
def retrieve_similar_examples(query, index, model, df, normalize=False, k=3):
    query_emb = model.encode(query, convert_to_numpy=True).reshape(1, -1)
    if normalize:
        query_emb = query_emb / np.linalg.norm(query_emb, axis=1, keepdims=True)

    distances, indices = index.search(query_emb, k)
    return df.iloc[indices[0]]

# функция генерации описания при помощи RAG
def generate_description_rag(input_text, index, model, df, normalize=False, k=3):
    retrieved = retrieve_similar_examples(input_text, index, model, df, normalize, k)

    prompt = "Сгенерируй описание одежды по характеристикам. Не выдумывай того, чего нет.\n"
    for _, row in retrieved.iterrows():
        prompt += f"\nХарактеристики:\n{row['text']}\nОписание:\n{row['final_desc']}\n"

    prompt += f"\nХарактеристики:\n{input_text}\nОписание:\n"

    response = client.chat.completions.create(
        model="gpt-4",
        messages=[{"role": "user", "content": prompt}],
        temperature=0.7,
        top_p=0.95,
        max_tokens=512,
        timeout=60
    )
    return retrieved, response.choices[0].message.content

# %%
# генерирую описания на тесте
from tqdm import tqdm

gen_list = []
for i, row in tqdm(df_test.iterrows(), total=len(df_test)):
    try:
      __, gen_rag = generate_description_rag(row["input"], index, model, df_embeddings, normalize=False, k=3)
      gen_list.append(gen_rag)

    except Exception as e:
        print(f"Ошибка на {i}: {e}")
        gen_list.append("")
# Out:
#  80%|███████▉  | 159/200 [49:04<07:30, 10.98s/it]
# Ошибка на 158: Error code: 429 - {'error': {'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, read the docs: https://platform.openai.com/docs/guides/error-codes/api-errors.', 'type': 'insufficient_quota', 'param': None, 'code': 'insufficient_quota'}}
#  80%|████████  | 160/200 [49:06<05:27,  8.19s/it]
# Ошибка на 159: Error code: 429 - {'error': {'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, read the docs: https://platform.openai.com/docs/guides/error-codes/api-errors.', 'type': 'insufficient_quota', 'param': None, 'code': 'insufficient_quota'}}
#  80%|████████  | 161/200 [49:08<04:03,  6.24s/it]
# Ошибка на 160: Error code: 429 - {'error': {'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, read the docs: https://platform.openai.com/docs/guides/error-codes/api-errors.', 'type': 'insufficient_quota', 'param': None, 'code': 'insufficient_quota'}}
#  81%|████████  | 162/200 [49:09<03:05,  4.88s/it]
# Ошибка на 161: Error code: 429 - {'error': {'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, read the docs: https://platform.openai.com/docs/guides/error-codes/api-errors.', 'type': 'insufficient_quota', 'param': None, 'code': 'insufficient_quota'}}
#  82%|████████▏ | 163/200 [49:11<02:23,  3.87s/it]
# Ошибка на 162: Error code: 429 - {'error': {'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, read the docs: https://platform.openai.com/docs/guides/error-codes/api-errors.', 'type': 'insufficient_quota', 'param': None, 'code': 'insufficient_quota'}}
#  82%|████████▏ | 164/200 [49:12<01:53,  3.16s/it]
# Ошибка на 163: Error code: 429 - {'error': {'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, read the docs: https://platform.openai.com/docs/guides/error-codes/api-errors.', 'type': 'insufficient_quota', 'param': None, 'code': 'insufficient_quota'}}
#  82%|████████▎ | 165/200 [49:14<01:33,  2.66s/it]
# Ошибка на 164: Error code: 429 - {'error': {'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, read the docs: https://platform.openai.com/docs/guides/error-codes/api-errors.', 'type': 'insufficient_quota', 'param': None, 'code': 'insufficient_quota'}}
#  83%|████████▎ | 166/200 [49:16<01:20,  2.36s/it]
# Ошибка на 165: Error code: 429 - {'error': {'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, read the docs: https://platform.openai.com/docs/guides/error-codes/api-errors.', 'type': 'insufficient_quota', 'param': None, 'code': 'insufficient_quota'}}
#  84%|████████▎ | 167/200 [49:17<01:09,  2.11s/it]
# Ошибка на 166: Error code: 429 - {'error': {'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, read the docs: https://platform.openai.com/docs/guides/error-codes/api-errors.', 'type': 'insufficient_quota', 'param': None, 'code': 'insufficient_quota'}}
#  84%|████████▍ | 168/200 [49:19<01:02,  1.96s/it]
# Ошибка на 167: Error code: 429 - {'error': {'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, read the docs: https://platform.openai.com/docs/guides/error-codes/api-errors.', 'type': 'insufficient_quota', 'param': None, 'code': 'insufficient_quota'}}
#  84%|████████▍ | 169/200 [49:20<00:56,  1.83s/it]
# Ошибка на 168: Error code: 429 - {'error': {'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, read the docs: https://platform.openai.com/docs/guides/error-codes/api-errors.', 'type': 'insufficient_quota', 'param': None, 'code': 'insufficient_quota'}}
#  85%|████████▌ | 170/200 [49:22<00:53,  1.77s/it]
# Ошибка на 169: Error code: 429 - {'error': {'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, read the docs: https://platform.openai.com/docs/guides/error-codes/api-errors.', 'type': 'insufficient_quota', 'param': None, 'code': 'insufficient_quota'}}
#  86%|████████▌ | 171/200 [49:23<00:49,  1.70s/it]
# Ошибка на 170: Error code: 429 - {'error': {'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, read the docs: https://platform.openai.com/docs/guides/error-codes/api-errors.', 'type': 'insufficient_quota', 'param': None, 'code': 'insufficient_quota'}}
#  86%|████████▌ | 172/200 [49:25<00:46,  1.68s/it]
# Ошибка на 171: Error code: 429 - {'error': {'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, read the docs: https://platform.openai.com/docs/guides/error-codes/api-errors.', 'type': 'insufficient_quota', 'param': None, 'code': 'insufficient_quota'}}
#  86%|████████▋ | 173/200 [49:26<00:43,  1.61s/it]
# Ошибка на 172: Error code: 429 - {'error': {'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, read the docs: https://platform.openai.com/docs/guides/error-codes/api-errors.', 'type': 'insufficient_quota', 'param': None, 'code': 'insufficient_quota'}}
#  87%|████████▋ | 174/200 [49:28<00:40,  1.56s/it]
# Ошибка на 173: Error code: 429 - {'error': {'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, read the docs: https://platform.openai.com/docs/guides/error-codes/api-errors.', 'type': 'insufficient_quota', 'param': None, 'code': 'insufficient_quota'}}
#  88%|████████▊ | 175/200 [49:30<00:39,  1.58s/it]
# Ошибка на 174: Error code: 429 - {'error': {'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, read the docs: https://platform.openai.com/docs/guides/error-codes/api-errors.', 'type': 'insufficient_quota', 'param': None, 'code': 'insufficient_quota'}}
#  88%|████████▊ | 176/200 [49:31<00:37,  1.56s/it]
# Ошибка на 175: Error code: 429 - {'error': {'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, read the docs: https://platform.openai.com/docs/guides/error-codes/api-errors.', 'type': 'insufficient_quota', 'param': None, 'code': 'insufficient_quota'}}
#  88%|████████▊ | 177/200 [49:33<00:37,  1.61s/it]
# Ошибка на 176: Error code: 429 - {'error': {'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, read the docs: https://platform.openai.com/docs/guides/error-codes/api-errors.', 'type': 'insufficient_quota', 'param': None, 'code': 'insufficient_quota'}}
#  89%|████████▉ | 178/200 [49:34<00:34,  1.56s/it]
# Ошибка на 177: Error code: 429 - {'error': {'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, read the docs: https://platform.openai.com/docs/guides/error-codes/api-errors.', 'type': 'insufficient_quota', 'param': None, 'code': 'insufficient_quota'}}
#  90%|████████▉ | 179/200 [49:36<00:32,  1.57s/it]
# Ошибка на 178: Error code: 429 - {'error': {'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, read the docs: https://platform.openai.com/docs/guides/error-codes/api-errors.', 'type': 'insufficient_quota', 'param': None, 'code': 'insufficient_quota'}}
#  90%|█████████ | 180/200 [49:37<00:30,  1.54s/it]
# Ошибка на 179: Error code: 429 - {'error': {'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, read the docs: https://platform.openai.com/docs/guides/error-codes/api-errors.', 'type': 'insufficient_quota', 'param': None, 'code': 'insufficient_quota'}}
#  90%|█████████ | 181/200 [49:39<00:28,  1.52s/it]
# Ошибка на 180: Error code: 429 - {'error': {'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, read the docs: https://platform.openai.com/docs/guides/error-codes/api-errors.', 'type': 'insufficient_quota', 'param': None, 'code': 'insufficient_quota'}}
#  91%|█████████ | 182/200 [49:40<00:28,  1.57s/it]
# Ошибка на 181: Error code: 429 - {'error': {'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, read the docs: https://platform.openai.com/docs/guides/error-codes/api-errors.', 'type': 'insufficient_quota', 'param': None, 'code': 'insufficient_quota'}}
#  92%|█████████▏| 183/200 [49:42<00:26,  1.56s/it]
# Ошибка на 182: Error code: 429 - {'error': {'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, read the docs: https://platform.openai.com/docs/guides/error-codes/api-errors.', 'type': 'insufficient_quota', 'param': None, 'code': 'insufficient_quota'}}
#  92%|█████████▏| 184/200 [49:43<00:24,  1.53s/it]
# Ошибка на 183: Error code: 429 - {'error': {'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, read the docs: https://platform.openai.com/docs/guides/error-codes/api-errors.', 'type': 'insufficient_quota', 'param': None, 'code': 'insufficient_quota'}}
#  92%|█████████▎| 185/200 [49:45<00:22,  1.52s/it]
# Ошибка на 184: Error code: 429 - {'error': {'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, read the docs: https://platform.openai.com/docs/guides/error-codes/api-errors.', 'type': 'insufficient_quota', 'param': None, 'code': 'insufficient_quota'}}
#  93%|█████████▎| 186/200 [49:47<00:21,  1.56s/it]
# Ошибка на 185: Error code: 429 - {'error': {'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, read the docs: https://platform.openai.com/docs/guides/error-codes/api-errors.', 'type': 'insufficient_quota', 'param': None, 'code': 'insufficient_quota'}}
#  94%|█████████▎| 187/200 [49:48<00:19,  1.53s/it]
# Ошибка на 186: Error code: 429 - {'error': {'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, read the docs: https://platform.openai.com/docs/guides/error-codes/api-errors.', 'type': 'insufficient_quota', 'param': None, 'code': 'insufficient_quota'}}
#  94%|█████████▍| 188/200 [49:50<00:18,  1.58s/it]
# Ошибка на 187: Error code: 429 - {'error': {'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, read the docs: https://platform.openai.com/docs/guides/error-codes/api-errors.', 'type': 'insufficient_quota', 'param': None, 'code': 'insufficient_quota'}}
#  94%|█████████▍| 189/200 [49:51<00:17,  1.62s/it]
# Ошибка на 188: Error code: 429 - {'error': {'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, read the docs: https://platform.openai.com/docs/guides/error-codes/api-errors.', 'type': 'insufficient_quota', 'param': None, 'code': 'insufficient_quota'}}
#  95%|█████████▌| 190/200 [49:53<00:16,  1.61s/it]
# Ошибка на 189: Error code: 429 - {'error': {'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, read the docs: https://platform.openai.com/docs/guides/error-codes/api-errors.', 'type': 'insufficient_quota', 'param': None, 'code': 'insufficient_quota'}}
#  96%|█████████▌| 191/200 [49:55<00:14,  1.62s/it]
# Ошибка на 190: Error code: 429 - {'error': {'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, read the docs: https://platform.openai.com/docs/guides/error-codes/api-errors.', 'type': 'insufficient_quota', 'param': None, 'code': 'insufficient_quota'}}
#  96%|█████████▌| 192/200 [49:56<00:12,  1.62s/it]
# Ошибка на 191: Error code: 429 - {'error': {'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, read the docs: https://platform.openai.com/docs/guides/error-codes/api-errors.', 'type': 'insufficient_quota', 'param': None, 'code': 'insufficient_quota'}}
#  96%|█████████▋| 193/200 [49:58<00:11,  1.67s/it]
# Ошибка на 192: Error code: 429 - {'error': {'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, read the docs: https://platform.openai.com/docs/guides/error-codes/api-errors.', 'type': 'insufficient_quota', 'param': None, 'code': 'insufficient_quota'}}
#  97%|█████████▋| 194/200 [50:00<00:09,  1.65s/it]
# Ошибка на 193: Error code: 429 - {'error': {'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, read the docs: https://platform.openai.com/docs/guides/error-codes/api-errors.', 'type': 'insufficient_quota', 'param': None, 'code': 'insufficient_quota'}}
#  98%|█████████▊| 195/200 [50:01<00:08,  1.65s/it]
# Ошибка на 194: Error code: 429 - {'error': {'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, read the docs: https://platform.openai.com/docs/guides/error-codes/api-errors.', 'type': 'insufficient_quota', 'param': None, 'code': 'insufficient_quota'}}
#  98%|█████████▊| 196/200 [50:03<00:06,  1.60s/it]
# Ошибка на 195: Error code: 429 - {'error': {'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, read the docs: https://platform.openai.com/docs/guides/error-codes/api-errors.', 'type': 'insufficient_quota', 'param': None, 'code': 'insufficient_quota'}}
#  98%|█████████▊| 197/200 [50:06<00:05,  1.97s/it]
# Ошибка на 196: Error code: 429 - {'error': {'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, read the docs: https://platform.openai.com/docs/guides/error-codes/api-errors.', 'type': 'insufficient_quota', 'param': None, 'code': 'insufficient_quota'}}
#  99%|█████████▉| 198/200 [50:07<00:03,  1.86s/it]
# Ошибка на 197: Error code: 429 - {'error': {'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, read the docs: https://platform.openai.com/docs/guides/error-codes/api-errors.', 'type': 'insufficient_quota', 'param': None, 'code': 'insufficient_quota'}}
# 100%|█████████▉| 199/200 [50:09<00:01,  1.79s/it]
# Ошибка на 198: Error code: 429 - {'error': {'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, read the docs: https://platform.openai.com/docs/guides/error-codes/api-errors.', 'type': 'insufficient_quota', 'param': None, 'code': 'insufficient_quota'}}
# 100%|██████████| 200/200 [50:10<00:00, 15.05s/it]
# Ошибка на 199: Error code: 429 - {'error': {'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, read the docs: https://platform.openai.com/docs/guides/error-codes/api-errors.', 'type': 'insufficient_quota', 'param': None, 'code': 'insufficient_quota'}}

# %%
df_test['rag_gen'] = gen_list
df_test.to_csv('drive/MyDrive/proj_cloth_desc_gen/df_sample_pred.csv')
